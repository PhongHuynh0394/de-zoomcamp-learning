# %% [markdown]
# # Ingest NY GREEN trip data

# %%
import pandas as pd
import gzip

# %%
green_taxi_url = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-09.csv.gz"
df = pd.read_csv(green_taxi_url, dtype={'store_and_fwd_flag': "object"})
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-09-01 00:10:53   2019-09-01 00:23:46
# 1            2.0  2019-09-01 00:31:22   2019-09-01 00:44:37
# 2            2.0  2019-09-01 00:50:24   2019-09-01 01:03:20
# 3            2.0  2019-09-01 00:27:06   2019-09-01 00:33:22
# 4            2.0  2019-09-01 00:43:23   2019-09-01 00:59:54
# ...          ...                  ...                   ...
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# 449061       NaN  2019-09-30 23:19:00   2019-10-01 00:06:00
# 449062       NaN  2019-09-30 23:35:00   2019-09-30 23:58:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0            65           189
# 1                       N         1.0            97           225
# 2                       N         1.0            37            61
# 3                       N         1.0           145           112
# 4                       N         1.0           112           198
# ...                   ...         ...           ...           ...
# 449058                NaN         NaN            66            71
# 449059                NaN         NaN            55            26
# 449060                NaN         NaN           139            78
# 449061                NaN         NaN           242           188
# 449062                NaN         NaN           155           189
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                   5.0           2.00        10.50   0.50      0.5
# 1                   5.0           3.20        12.00   0.50      0.5
# 2                   5.0           2.99        12.00   0.50      0.5
# 3                   1.0           1.73         7.50   0.50      0.5
# 4                   1.0           3.42        14.00   0.50      0.5
# ...                 ...            ...          ...    ...      ...
# 449058              NaN           7.84        43.25   2.75      0.5
# 449059              NaN           3.56        25.75   2.75      0.5
# 449060              NaN          18.47        50.47   2.75      0.5
# 449061              NaN          20.10        58.22   2.75      0.5
# 449062              NaN           5.87        26.07   2.75      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0             2.36          0.00        NaN                    0.3
# 1             0.00          0.00        NaN                    0.3
# 2             0.00          0.00        NaN                    0.3
# 3             1.50          0.00        NaN                    0.3
# 4             3.06          0.00        NaN                    0.3
# ...            ...           ...        ...                    ...
# 449058        0.00          0.00        NaN                    0.0
# 449059        0.00          0.00        NaN                    0.0
# 449060        0.00          6.12        NaN                    0.0
# 449061        0.00          6.12        NaN                    0.0
# 449062        0.00          0.00        NaN                    0.0
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 0              14.16           1.0        1.0                   0.0
# 1              13.30           2.0        1.0                   0.0
# 2              13.30           2.0        1.0                   0.0
# 3              10.30           1.0        1.0                   0.0
# 4              18.36           1.0        1.0                   0.0
# ...              ...           ...        ...                   ...
# 449058         46.50           NaN        NaN                   NaN
# 449059         29.00           NaN        NaN                   NaN
# 449060         59.84           NaN        NaN                   NaN
# 449061         67.59           NaN        NaN                   NaN
# 449062         29.32           NaN        NaN                   NaN
#
# [449063 rows x 20 columns]

# %%
df.dtypes
# Out:
# VendorID                 float64
# lpep_pickup_datetime      object
# lpep_dropoff_datetime     object
# store_and_fwd_flag        object
# RatecodeID               float64
# PULocationID               int64
# DOLocationID               int64
# passenger_count          float64
# trip_distance            float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# ehail_fee                float64
# improvement_surcharge    float64
# total_amount             float64
# payment_type             float64
# trip_type                float64
# congestion_surcharge     float64
# dtype: object

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.dtypes
# Out:
# VendorID                        float64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %% [markdown]
# Number of taxi trip in September 18th 2019

# %%
start_day = '2019-09-18 00:00:00'
end_day = '2019-09-18 23:59:59'
taxi = df[(df['lpep_pickup_datetime'] >= start_day) & (df['lpep_dropoff_datetime'] <= end_day)]
len(taxi)
# Out:
# 15612

# %% [markdown]
# pick up day with the largest trip distance

# %%
df.sort_values(by="trip_distance", ascending=False)[['lpep_pickup_datetime','trip_distance']]
# Out:
#        lpep_pickup_datetime  trip_distance
# 337292  2019-09-26 19:32:52         341.64
# 260941  2019-09-21 00:18:15         135.53
# 194647  2019-09-16 07:17:37         114.30
# 355914  2019-09-28 03:30:40          89.64
# 300408  2019-09-24 01:16:42          82.12
# ...                     ...            ...
# 236791  2019-09-19 13:50:01           0.00
# 352177  2019-09-27 21:19:05           0.00
# 109394  2019-09-09 14:54:41           0.00
# 197868  2019-09-16 11:28:05           0.00
# 132304  2019-09-11 15:15:55           0.00
#
# [449063 rows x 2 columns]

# %% [markdown]
# Read Zone data

# %%
zone_url = "https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv"
zone = pd.read_csv(zone_url)
zone.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
taxi_zone = pd.merge(df, zone, left_on="PULocationID", right_on="LocationID", how="inner")
taxi_zone
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-09-01 00:10:53   2019-09-01 00:23:46
# 1            2.0  2019-09-01 00:31:22   2019-09-01 00:44:37
# 2            2.0  2019-09-01 00:50:24   2019-09-01 01:03:20
# 3            2.0  2019-09-01 00:27:06   2019-09-01 00:33:22
# 4            2.0  2019-09-01 00:43:23   2019-09-01 00:59:54
# ...          ...                  ...                   ...
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# 449061       NaN  2019-09-30 23:19:00   2019-10-01 00:06:00
# 449062       NaN  2019-09-30 23:35:00   2019-09-30 23:58:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0            65           189
# 1                       N         1.0            97           225
# 2                       N         1.0            37            61
# 3                       N         1.0           145           112
# 4                       N         1.0           112           198
# ...                   ...         ...           ...           ...
# 449058                NaN         NaN            66            71
# 449059                NaN         NaN            55            26
# 449060                NaN         NaN           139            78
# 449061                NaN         NaN           242           188
# 449062                NaN         NaN           155           189
#
#         passenger_count  trip_distance  fare_amount  ...  ehail_fee  \
# 0                   5.0           2.00        10.50  ...        NaN
# 1                   5.0           3.20        12.00  ...        NaN
# 2                   5.0           2.99        12.00  ...        NaN
# 3                   1.0           1.73         7.50  ...        NaN
# 4                   1.0           3.42        14.00  ...        NaN
# ...                 ...            ...          ...  ...        ...
# 449058              NaN           7.84        43.25  ...        NaN
# 449059              NaN           3.56        25.75  ...        NaN
# 449060              NaN          18.47        50.47  ...        NaN
# 449061              NaN          20.10        58.22  ...        NaN
# 449062              NaN           5.87        26.07  ...        NaN
#
#         improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                         0.3         14.16           1.0        1.0
# 1                         0.3         13.30           2.0        1.0
# 2                         0.3         13.30           2.0        1.0
# 3                         0.3         10.30           1.0        1.0
# 4                         0.3         18.36           1.0        1.0
# ...                       ...           ...           ...        ...
# 449058                    0.0         46.50           NaN        NaN
# 449059                    0.0         29.00           NaN        NaN
# 449060                    0.0         59.84           NaN        NaN
# 449061                    0.0         67.59           NaN        NaN
# 449062                    0.0         29.32           NaN        NaN
#
#         congestion_surcharge  LocationID   Borough  \
# 0                        0.0          65  Brooklyn
# 1                        0.0          97  Brooklyn
# 2                        0.0          37  Brooklyn
# 3                        0.0         145    Queens
# 4                        0.0         112  Brooklyn
# ...                      ...         ...       ...
# 449058                   NaN          66  Brooklyn
# 449059                   NaN          55  Brooklyn
# 449060                   NaN         139    Queens
# 449061                   NaN         242     Bronx
# 449062                   NaN         155  Brooklyn
#
#                                   Zone  service_zone
# 0          Downtown Brooklyn/MetroTech     Boro Zone
# 1                          Fort Greene     Boro Zone
# 2                       Bushwick South     Boro Zone
# 3       Long Island City/Hunters Point     Boro Zone
# 4                           Greenpoint     Boro Zone
# ...                                ...           ...
# 449058              DUMBO/Vinegar Hill     Boro Zone
# 449059                    Coney Island     Boro Zone
# 449060                       Laurelton     Boro Zone
# 449061            Van Nest/Morris Park     Boro Zone
# 449062          Marine Park/Mill Basin     Boro Zone
#
# [449063 rows x 24 columns]

# %% [markdown]
# Which were the 3 pick up Boroughs that had a sum of total_amount superior to 50000?

# %%
a = taxi_zone.groupby("Borough").agg({"total_amount": "sum"})
a[a['total_amount'] >= 50000]
# Out:
#            total_amount
# Borough
# Bronx         818158.06
# Brooklyn     2619378.54
# Manhattan    2427880.92
# Queens       2460386.17

# %%
ast_sep = taxi_zone[(taxi_zone["Zone"] == "Astoria") & (taxi_zone["lpep_pickup_datetime"].dt.month == 9)]
ast_sep = ast_sep.sort_values("tip_amount", ascending=False)[['DOLocationID', 'tip_amount']]
ast_sep = pd.merge(ast_sep, zone, left_on="DOLocationID", right_on="LocationID", how="inner")
ast_sep
# Out:
#        DOLocationID  tip_amount  LocationID    Borough                   Zone  \
# 0               132       62.31         132     Queens            JFK Airport
# 1               260       30.00         260     Queens               Woodside
# 2               137       28.00         137  Manhattan               Kips Bay
# 3               264       25.00         264    Unknown                     NV
# 4               239       20.00         239  Manhattan  Upper West Side South
# ...             ...         ...         ...        ...                    ...
# 18257            82        0.00          82     Queens               Elmhurst
# 18258             7        0.00           7     Queens                Astoria
# 18259           129        0.00         129     Queens        Jackson Heights
# 18260           179        0.00         179     Queens            Old Astoria
# 18261            82        0.00          82     Queens               Elmhurst
#
#       service_zone
# 0         Airports
# 1        Boro Zone
# 2      Yellow Zone
# 3              NaN
# 4      Yellow Zone
# ...            ...
# 18257    Boro Zone
# 18258    Boro Zone
# 18259    Boro Zone
# 18260    Boro Zone
# 18261    Boro Zone
#
# [18262 rows x 6 columns]

# %% [markdown]
# ## Ingesting into PSQL

# %%
from sqlalchemy import create_engine

# %% [markdown]
# Generate DDL statements to create table in Postgres

# %%
engine = create_engine('postgresql://root:root@postgres:5432/ny_taxi') #need to chang localhost to postgres cause in docker network

engine.connect()

# %% [markdown]
# Connect to psql

# %%
print(pd.io.sql.get_schema(df, name="green_taxi_data", con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" FLOAT(53),
# 	lpep_pickup_datetime TEXT,
# 	lpep_dropoff_datetime TEXT,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" FLOAT(53),
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type FLOAT(53),
# 	trip_type FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
chunk_size = 100_000
df = pd.read_csv(green_taxi_url, dtype={'store_and_fwd_flag': "string"}, chunksize=chunk_size)

# %%
from time import time
for i, chunk in enumerate(df):
    # Some simple cleaning
    chunk.lpep_pickup_datetime = pd.to_datetime(chunk.lpep_pickup_datetime)
    chunk.lpep_dropoff_datetime = pd.to_datetime(chunk.lpep_dropoff_datetime)

    # Push into psql
    try:
        start = time()
        chunk.to_sql(name='green_taxi_data', con=engine, if_exists='append')
        end = time()
        print(f"Chunk {i+1}: Successfully Ingesting {len(chunk)} into PSQL... take {round(end-start,2)} Sec")
    except Exception as e:
        print(e)
        print(f"Failed at chunk {i}, skip...")
# Out:
# Chunk 1: Successfully Ingesting 100000 into PSQL... take 9.42 Sec
# Chunk 2: Successfully Ingesting 100000 into PSQL... take 9.4 Sec
# Chunk 3: Successfully Ingesting 100000 into PSQL... take 10.14 Sec
# Chunk 4: Successfully Ingesting 100000 into PSQL... take 12.97 Sec
# Chunk 5: Successfully Ingesting 49063 into PSQL... take 4.64 Sec

# %%
df = pd.read_csv(zone_url, chunksize=chunk_size)
table = "zone"
for i, chunk in enumerate(df):
    # Push into psql
    try:
        start = time()
        chunk.to_sql(name=table, con=engine, if_exists='append')
        end = time()
        print(f"Chunk {i+1}: Successfully Ingesting {len(chunk)} into PSQL... take {round(end-start,2)} Sec")
    except Exception as e:
        print(e)
        print(f"Failed at chunk {i}, skip...")
# Out:
# Chunk 1: Successfully Ingesting 265 into PSQL... take 0.04 Sec

# %%
df
